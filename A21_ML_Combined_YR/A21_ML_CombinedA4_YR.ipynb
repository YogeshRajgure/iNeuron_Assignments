# %% [markdown]
# <a href="https://colab.research.google.com/github/YogeshRajgure/iNeuron_Assignments/blob/main/A21_ML_Combined_YR/A21_ML_CombinedA4_YR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 4

# %% [markdown]
# In this assignment students have to transform iris data into 3 dimensions
# and plot a 3d chart with transformed dimensions and colour each data
# point with specific class.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import decomposition
from sklearn import datasets

# %%
data = datasets.load_iris()
df =pd.DataFrame(data['data'], columns = data['feature_names'])
df['target'] = data['target']
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)  target
# 0                5.1               3.5  ...               0.2       0
# 1                4.9               3.0  ...               0.2       0
# 2                4.7               3.2  ...               0.2       0
# 3                4.6               3.1  ...               0.2       0
# 4                5.0               3.6  ...               0.2       0
#
# [5 rows x 5 columns]

# %%
df.target.unique()
# Out:
# array([0, 1, 2])

# %%
# dividing data into x & y

# %%
X = df.drop(columns=['target'])
y = df['target']

# %%
# data encoding and tranforming

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder_y = LabelEncoder()

# %%
y = label_encoder_y.fit_transform(y)

# %%
# standard scaling

# %%
from sklearn.preprocessing import StandardScaler

scalar = StandardScaler()
x_std = scalar.fit_transform(X)

# %%
# transforming data into 3 Dimensions using PCA

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=3)
x_3d = pca.fit_transform(x_std)

# %%
# visualizing

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
# %matplotlib inline

fig = plt.figure(1, figsize=(8, 8))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
plt.cla()
ax.scatter(x_3d[:, 0], x_3d[:, 1], x_3d[:, 2], c=y,
           cmap=plt.cm.coolwarm)

ax.set_title("First three PCA directions")
ax.set_xlabel("1st eigenvector")
# ax.w_xaxis.set_ticklabels([])

ax.set_ylabel("2nd eigenvector")
# ax.w_yaxis.set_ticklabels([])


ax.set_zlabel("3rd eigenvector")
# ax.w_zaxis.set_ticklabels([])

plt.show()
